# %%
import pandas as pd
from clearml import Task
import numpy as np
import h5py
import os
from pathlib import Path
import re
from datetime import datetime
import dask.dataframe as dd
import gc

def find_latest_h5_file(task_id, base_dir="/scratch/clearml/offline_logs/"):
    """Find the latest h5 file for a given task_id"""
    base_path = Path(base_dir)
    
    pattern = f"metrics_{task_id}*.h5"
    matching_files = list(base_path.glob(pattern))
    
    if not matching_files:
        print(f"  No h5 file found for task {task_id}")
        return None
    
    if len(matching_files) == 1:
        print(f"  Found h5 file: {matching_files[0].name}")
        return matching_files[0]
    
    files_with_timestamps = []
    for file_path in matching_files:
        filename = file_path.name
        timestamp_match = re.search(f"metrics_{task_id}_(.+)\\.h5", filename)
        if timestamp_match:
            timestamp_str = timestamp_match.group(1)
            try:
                timestamp = float(timestamp_str)
            except ValueError:
                try:
                    timestamp = datetime.strptime(timestamp_str, "%Y%m%d_%H%M%S").timestamp()
                except:
                    timestamp = 0
            files_with_timestamps.append((file_path, timestamp))
        else:
            files_with_timestamps.append((file_path, 0))
    
    latest_file = max(files_with_timestamps, key=lambda x: x[1])[0]
    print(f"  Multiple h5 files found, using latest: {latest_file.name}")
    return latest_file

def debug_h5_structure(h5_path):
    """Debug function to inspect h5 file structure"""
    print(f"\nDEBUGGING H5 FILE: {h5_path}")
    
    with h5py.File(h5_path, 'r') as f:
        def print_structure(name, obj):
            if isinstance(obj, h5py.Dataset):
                print(f"Dataset: {name}")
                print(f"  Shape: {obj.shape}")
                print(f"  Dtype: {obj.dtype}")
                if obj.size < 10:
                    print(f"  Data preview: {obj[:]}")
                else:
                    print(f"  Data preview (first 5): {obj[:5]}")
        
        print("H5 File Structure:")
        f.visititems(print_structure)
        print(f"\nRoot level keys: {list(f.keys())}")

def read_h5_metrics(h5_path):
    """Read metrics from h5 file and return as structured dictionary"""
    metrics = {}
    
    with h5py.File(h5_path, 'r') as f:
        metric_names = set()
        for key in f.keys():
            if not key.endswith('_iterations'):
                metric_names.add(key)
        
        for metric_name in metric_names:
            iteration_key = f"{metric_name}_iterations"
            
            if metric_name in f:
                values = f[metric_name][:]
                iterations = f[iteration_key][:] if iteration_key in f else None
                
                metrics[metric_name] = {
                    'values': values,
                    'iterations': iterations
                }
    
    return metrics

def download_and_process_tasks_from_h5_normalized(tag, experiment_name, base_dir="/scratch/clearml/offline_logs/", 
                                                   debug_first=True, batch_size=20, 
                                                   metadata_path=None, timeseries_path=None):
    """Download tasks and save as normalized tables: metadata + timeseries"""
    print(f"DOWNLOADING TASKS FOR {experiment_name}: {tag}")
    tasks = Task.get_tasks(project_name="oho", tags=[tag], allow_archived=False)
    print(f"Found {len(tasks)} tasks (excluding archived)")
    
    if not metadata_path or not timeseries_path:
        raise ValueError("Both metadata_path and timeseries_path are required")
    
    print(f"Will save metadata to: {metadata_path}")
    print(f"Will save timeseries to: {timeseries_path}")
    
    # Create directories if they don't exist
    os.makedirs(os.path.dirname(metadata_path), exist_ok=True)
    os.makedirs(os.path.dirname(timeseries_path), exist_ok=True)
    
    # Remove existing files
    if os.path.exists(metadata_path):
        os.remove(metadata_path)
    if os.path.exists(timeseries_path):
        os.remove(timeseries_path)
    
    h5_files_found = 0
    h5_files_missing = 0
    total_metadata_rows = 0
    total_timeseries_rows = 0
    
    metadata_rows = []
    
    for batch_start in range(0, len(tasks), batch_size):
        batch_end = min(batch_start + batch_size, len(tasks))
        batch_tasks = tasks[batch_start:batch_end]
        print(f"\nProcessing batch {batch_start + 1}-{batch_end}/{len(tasks)}")
        
        timeseries_rows = []
        
        for idx, task in enumerate(batch_tasks):
            task_id = task.id
            task_name = task.name
            
            # Metadata row (one per task)
            metadata_row = {"task_id": task_id, "task_name": task_name}
            params = task.get_parameters() or {}
            for key, value in params.items():
                if any(x in key for x in ["learning_rate", "optimizer/_type", "seed/global_seed"]):
                    metadata_row[key] = value
            
            h5_path = find_latest_h5_file(task_id, base_dir)
            
            if h5_path is None:
                h5_files_missing += 1
                metadata_rows.append(metadata_row)
                continue
            
            h5_files_found += 1
            
            if debug_first and h5_files_found == 1:
                debug_h5_structure(h5_path)
            
            try:
                metrics = read_h5_metrics(h5_path)
                
                # Separate scalar (final_*) from timeseries
                scalar_metrics = {}
                timeseries_metrics = {}
                
                for metric_name, metric_data in metrics.items():
                    values = metric_data['values']
                    iterations = metric_data['iterations']
                    
                    if metric_name.startswith('final_'):
                        # Add to metadata
                        scalar_metrics[f"metric/{metric_name}"] = values[0] if len(values) > 0 else np.nan
                    elif iterations is not None and len(values) == len(iterations):
                        timeseries_metrics[metric_name] = metric_data
                
                # Add scalar metrics to metadata row
                metadata_row.update(scalar_metrics)
                metadata_rows.append(metadata_row)
                
                # Create timeseries rows (many per task)
                if timeseries_metrics:
                    ref_metric = list(timeseries_metrics.keys())[0]
                    iterations = timeseries_metrics[ref_metric]['iterations']
                    
                    for iter_idx, iteration in enumerate(iterations):
                        ts_row = {
                            "task_id": task_id,
                            "iteration": int(iteration)
                        }
                        
                        for metric_name, metric_data in timeseries_metrics.items():
                            if iter_idx < len(metric_data['values']):
                                ts_row[f"metric/{metric_name}"] = metric_data['values'][iter_idx]
                        
                        timeseries_rows.append(ts_row)
                    
            except Exception as e:
                print(f"  ERROR reading h5 file: {e}")
                import traceback
                traceback.print_exc()
                h5_files_missing += 1
                metadata_rows.append(metadata_row)
        
        # Save timeseries batch
        if timeseries_rows:
            ts_batch_df = pd.DataFrame(timeseries_rows)
            total_timeseries_rows += len(ts_batch_df)
            
            if batch_start == 0:
                ts_batch_df.to_parquet(timeseries_path, index=False)
            else:
                existing_ts = pd.read_parquet(timeseries_path)
                combined_ts = pd.concat([existing_ts, ts_batch_df], ignore_index=True)
                combined_ts.to_parquet(timeseries_path, index=False)
            
            print(f"  Saved timeseries batch ({len(ts_batch_df)} rows)")
            
            del timeseries_rows
            del ts_batch_df
            if batch_start > 0:
                del existing_ts
                del combined_ts
            gc.collect()
    
    # Save all metadata at once (only 300 rows, no need to batch)
    if metadata_rows:
        metadata_df = pd.DataFrame(metadata_rows)
        metadata_df.to_parquet(metadata_path, index=False)
        total_metadata_rows = len(metadata_df)
        print(f"\nSaved metadata ({total_metadata_rows} rows) to {metadata_path}")
    
    print(f"\n=== SUMMARY ===")
    print(f"Total tasks: {len(tasks)}")
    print(f"H5 files found: {h5_files_found}")
    print(f"H5 files missing: {h5_files_missing}")
    print(f"Total metadata rows: {total_metadata_rows}")
    print(f"Total timeseries rows: {total_timeseries_rows}")
    
    # Load as Dask DataFrames
    print(f"\nLoading as Dask DataFrames")
    df_metadata = dd.read_parquet(metadata_path)
    df_timeseries = dd.read_parquet(timeseries_path)
    
    print(f"\nMetadata DataFrame: {df_metadata.npartitions} partitions")
    print(f"Columns: {df_metadata.columns.tolist()}")
    print(f"Sample:")
    print(df_metadata.head(5))
    
    print(f"\nTimeseries DataFrame: {df_timeseries.npartitions} partitions")
    print(f"Columns: {df_timeseries.columns.tolist()}")
    print(f"Sample:")
    print(df_timeseries.head(5))
    
    return df_metadata, df_timeseries

# %%
# Usage
df_metadata_exp1, df_timeseries_exp1 = download_and_process_tasks_from_h5_normalized(
    tag="opt: 04a046a61f6e465aa834eb1853f00916", 
    experiment_name="Fixed LR",
    base_dir="/scratch/clearml/offline_logs/",
    debug_first=True,
    batch_size=20,
    metadata_pxath="/scratch/clearml/processed_data/fixed_lr_metadata.parquet",
    timeseries_path="/scratch/clearml/processed_data/fixed_lr_timeseries.parquet"
)
# Out:
# DOWNLOADING TASKS FOR Fixed LR: opt: 04a046a61f6e465aa834eb1853f00916
# Found 300 tasks (excluding archived)
# Will save metadata to: /scratch/clearml/processed_data/fixed_lr_metadata.parquet
# Will save timeseries to: /scratch/clearml/processed_data/fixed_lr_timeseries.parquet
#
# Processing batch 1-20/300
#   Found h5 file: metrics_0104269388204f66940dd66d3ab96e6f.h5
#
# DEBUGGING H5 FILE: /scratch/clearml/offline_logs/metrics_0104269388204f66940dd66d3ab96e6f.h5
# H5 File Structure:
# Dataset: final_test_accuracy
#   Shape: (1,)
#   Dtype: float64
#   Data preview: [0.10000003]
# Dataset: final_test_accuracy_iterations
#   Shape: (1,)
#   Dtype: int32
#   Data preview: [50000]
# Dataset: final_test_loss
#   Shape: (1,)
#   Dtype: float64
#   Data preview: [28.15073204]
# Dataset: final_test_loss_iterations
#   Shape: (1,)
#   Dtype: int32
#   Data preview: [50000]
# Dataset: meta_gradient_norm
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [0. 0. 0. 0. 0.]
# Dataset: meta_gradient_norm_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: test_accuracy
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [0.15000001 0.44       0.18000001 0.40000001 0.07      ]
# Dataset: test_accuracy_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: test_loss
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [2.46578979 1.88946736 2.56240058 2.56736612 4.2136116 ]
# Dataset: test_loss_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: train_accuracy
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [0.05       0.14       0.38999999 0.2        0.28      ]
# Dataset: train_accuracy_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: train_gradient_norm
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [0.         1.70139623 3.31793237 2.13150454 4.76231813]
# Dataset: train_gradient_norm_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: train_learning_rate
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [0.69999999 0.69999999 0.69999999 0.69999999 0.69999999]
# Dataset: train_learning_rate_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: train_loss
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [2.31328464 2.50235319 1.99479127 2.43923879 2.81592274]
# Dataset: train_loss_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: train_weight_decay
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [0. 0. 0. 0. 0.]
# Dataset: train_weight_decay_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: validation_accuracy
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [0.12       0.41999999 0.2        0.34999999 0.11      ]
# Dataset: validation_accuracy_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: validation_loss
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [2.42914987 2.08816123 2.48765492 2.86837029 3.83816385]
# Dataset: validation_loss_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
#
# Root level keys: ['final_test_accuracy', 'final_test_accuracy_iterations', 'final_test_loss', 'final_test_loss_iterations', 'meta_gradient_norm', 'meta_gradient_norm_iterations', 'test_accuracy', 'test_accuracy_iterations', 'test_loss', 'test_loss_iterations', 'train_accuracy', 'train_accuracy_iterations', 'train_gradient_norm', 'train_gradient_norm_iterations', 'train_learning_rate', 'train_learning_rate_iterations', 'train_loss', 'train_loss_iterations', 'train_weight_decay', 'train_weight_decay_iterations', 'validation_accuracy', 'validation_accuracy_iterations', 'validation_loss', 'validation_loss_iterations']
#   Found h5 file: metrics_28ab164aeaf441099d2ad236488f1c2f.h5
#   Found h5 file: metrics_1c5004704a4e46799a26a38517d10ff8.h5
#   Found h5 file: metrics_95c7f79186d84487ba88024d995ee986.h5
#   Found h5 file: metrics_910984d867d34a94b779f9fc81293e73.h5
#   Found h5 file: metrics_3e09cda67b56432b880db1b51c6c476c.h5
#   Found h5 file: metrics_05b6cd8dacc24b6d909e3171f9120bc9.h5
#   Found h5 file: metrics_e3fa58031700485c8517dfb0deff6b7b.h5
#   Found h5 file: metrics_8a5b2d56bea9461b9477871f5c6cabd6.h5
#   Found h5 file: metrics_bba6d2a836134db38feaf816e57099e3.h5
#   Found h5 file: metrics_b572c98276544c3aa0e5c12fc103a738.h5
#   Found h5 file: metrics_d19c472e6c4a4124b12ee72da744f1d5.h5
#   Found h5 file: metrics_c7e879ce421347878dbf9c17d66d3273.h5
#   Found h5 file: metrics_a288d71116c0404d9f774906416f4f43.h5
#   Found h5 file: metrics_eae8a41a7a3f470cb2d3fa1cfddbd9b2.h5
#   Found h5 file: metrics_32532c009bf047009608954063e9f8ae.h5
#   Found h5 file: metrics_1151e84c302f44fc9e3ab0d992b778e0.h5
#   Found h5 file: metrics_52713a04c71146d49e24dd9c2a06ad9d.h5
#   Found h5 file: metrics_9fa92517166a45f296d6db7a7b9581c1.h5
#   Found h5 file: metrics_8c601a7616b84a99ae392f9c6ea96de7.h5
#   Saved timeseries batch (1000000 rows)
#
# Processing batch 21-40/300
#   Found h5 file: metrics_af13912749cc44dba5fcd2510b7a14a9.h5
#   Found h5 file: metrics_b09b37d4908546f9b7fa5bcc1fb047f8.h5
#   Found h5 file: metrics_0e3420abf64041738cff96084486fc2c.h5
#   Found h5 file: metrics_0d84384b778b44c0bf18469ff8fbe61c.h5
#   Found h5 file: metrics_3313b287a2114a399fead1bd75dea389.h5
#   Found h5 file: metrics_01642f0c40504ad29d9129bf5625365e.h5
#   Found h5 file: metrics_fafb3052371640a28efee2dc69df7d5f.h5
#   Found h5 file: metrics_8c3678d7f26c415da1fbd88299a79a21.h5
#   Found h5 file: metrics_544a88d0843f4884aa8b18000d63463d.h5
#   Found h5 file: metrics_81c37df191154df184f7b792a4d3fbe4.h5
#   Found h5 file: metrics_5ced376eec5449f290b40ff6efad1db4.h5
#   Found h5 file: metrics_e9c3203385eb4eb8a64e9850d6826451.h5
#   Found h5 file: metrics_d2cf96400c8840829dec72c93c3db0a2.h5
#   Found h5 file: metrics_83e43e1f05534724bd012b816580e221.h5
#   Found h5 file: metrics_8f024c8e35d84e2486ee069c2d7949ba.h5
#   Found h5 file: metrics_0dec0d29aa3e44bfbe3c1a0114f61e33.h5
#   Found h5 file: metrics_405b9dbf393e44409b18b0b33f531464.h5
#   Found h5 file: metrics_fdf23369145b4efc9d10cd5b543a0605.h5
#   Found h5 file: metrics_eb0fe3448a684dddb3c7b4c247a7897d.h5
#   Found h5 file: metrics_253103e5d57a4ae292561d158bfc1cff.h5
#   Saved timeseries batch (1000000 rows)
#
# Processing batch 41-60/300
#   Found h5 file: metrics_89f1b42c467c40898d79ff292d99ed0c.h5
#   Found h5 file: metrics_077bca6166274fdd8352be093c180f09.h5
#   Found h5 file: metrics_b4da81899b2d4f69a1861dd81a67a11a.h5
#   Found h5 file: metrics_6b7c45e8a9384a6fa9e5da97749c190d.h5
#   Found h5 file: metrics_5dc1dc5c11b24432a0d826929a7e77dd.h5
#   Found h5 file: metrics_f72a05fb45c549c5976d91142f962308.h5
#   Found h5 file: metrics_cc49b26cec044fc3aa7561defc6346dc.h5
#   Found h5 file: metrics_d3758d0efa0749bba8498c320cf5b58c.h5
#   Found h5 file: metrics_f072669cc83f4baf9e595299d9fa2854.h5
#   Found h5 file: metrics_5ba2c28f82cc4771892765a643f70bc7.h5
#   Found h5 file: metrics_fe07249a2ebc4ca192bb57bff3c76185.h5
#   Found h5 file: metrics_a565e4bf5d8d4d3395a76c3ace35fbda.h5
#   Found h5 file: metrics_00fb0f7ccd3a49c9b55bcb7621eeeaa5.h5
#   Found h5 file: metrics_0c2eb99c45884fb68f07717c7c911c58.h5
#   Found h5 file: metrics_52d79204a357456bae4113be0c1e1c8a.h5
#   Found h5 file: metrics_eb7c8c0fc052483c8610eea8236c716e.h5
#   Found h5 file: metrics_e40ad11d22e94a57a5adadf91858e96b.h5
#   Found h5 file: metrics_d15f59fc04684873acc11789a51e437d.h5
#   Found h5 file: metrics_789111b274904efa9caff3b82744ad6e.h5
#   Found h5 file: metrics_64530717886d45118d732d30d4f6c92c.h5
#   Saved timeseries batch (1000000 rows)
#
# Processing batch 61-80/300
#   Found h5 file: metrics_7165f381ad5846198448a3b45bea0d3b.h5
#   Found h5 file: metrics_8f0c73e3da1d438bb51eda0d51b040a8.h5
#   Found h5 file: metrics_715a41550c1243a587c0a20da605b1c9.h5
#   Found h5 file: metrics_eb9dfe24f2904b3da76dd79c60b8f9ac.h5
#   Found h5 file: metrics_03f1b8dce4f743bca9ddced40d0171bc.h5
#   Found h5 file: metrics_999344540663444fb88b48b594f63a34.h5
#   Found h5 file: metrics_babd79516451445dbd7fd0059be9e0ce.h5
#   Found h5 file: metrics_373535ee900848a4aa00150cdde3c8ed.h5
#   Found h5 file: metrics_0c1593a85aab43db8ab97e7088a481e4.h5
#   Found h5 file: metrics_f77e722a9c26426ba8432ab2163665d5.h5
#   Found h5 file: metrics_fea763ada0d945d2bbd7d8be8254565e.h5
#   Found h5 file: metrics_49ef723d9c024cb09163e73ab3935610.h5
#   Found h5 file: metrics_e4620e615d2742ad8a628d9f244c7b45.h5
#   Found h5 file: metrics_5a7b675a658e43f7a23221bda04485a5.h5
#   Found h5 file: metrics_79cc17a615614f879e3d2a15353a2e5e.h5
#   Found h5 file: metrics_f264dc756d2a4c4089347ffba4412126.h5
#   Found h5 file: metrics_5a692303f1de4b669a1c2a408cb39c42.h5
#   Found h5 file: metrics_4f73a204b4b0470385b684ce3985462e.h5
#   Found h5 file: metrics_235eb4f9170b4740ad2179e60e9dc6dc.h5
#   Found h5 file: metrics_6bd12e6f869446cd99c11ecd610444f9.h5
#   Saved timeseries batch (1000000 rows)
#
# Processing batch 81-100/300
#   Found h5 file: metrics_f4fee80b58aa4e9cbdb82a2e7d13c031.h5
#   Found h5 file: metrics_99b0c6b608ee405b80d7e5f6c5a60e06.h5
#   Found h5 file: metrics_575a669e3df54d278fdd34a549677a4e.h5
#   Found h5 file: metrics_ada05d904356470a8d15e3414efe5193.h5
#   Found h5 file: metrics_6357a19a8c954f128aac4c9da5be7f11.h5
#   Found h5 file: metrics_36c0499fe03d4982a3d0adc0f10f3196.h5
#   Found h5 file: metrics_7d9bb68962064e09a7c4a6ee4933e23d.h5
#   Found h5 file: metrics_e9ec07f02a574fb8bed47e955bfea8fa.h5
#   Found h5 file: metrics_de689f38c156468db8e1f0d0e83bf672.h5
#   Found h5 file: metrics_afa3dbfd36394356a2a3df775b94e1ab.h5
#   Found h5 file: metrics_8d4ee4be8ae441b0b666751175b53156.h5
#   Found h5 file: metrics_bf723e54bd234d94948b505d609d1990.h5
#   Found h5 file: metrics_c9cf457f55444eec8f44842d8da0e847.h5
#   Found h5 file: metrics_8e383786266f42558f641e432fb2d724.h5
#   Found h5 file: metrics_4bde0f90e7764cef8ce00bb50760e538.h5
#   Found h5 file: metrics_272a3e7395a8439b909377e66fa398f2.h5
#   Found h5 file: metrics_3e90c7b569c1465a89157b13fddec25d.h5
#   Found h5 file: metrics_def02c5f6e93456a916c367edfccc198.h5
#   Found h5 file: metrics_62feed2087cd445591cfb2b646c48a99.h5
#   Found h5 file: metrics_fb89be8b4a984500a1d8b63a07556dc3.h5
#   Saved timeseries batch (1000000 rows)
#
# Processing batch 101-120/300
#   Found h5 file: metrics_d4d2b9375bc64a998e7bfb0d91a31716.h5
#   Found h5 file: metrics_c1171acad2b74670a6f78e4309d605a3.h5
#   Found h5 file: metrics_a0de0a5647f04a538f8985d7b9385a00.h5
#   Found h5 file: metrics_7a47d9ef4754483096673763834c1314.h5
#   Found h5 file: metrics_84e1e00590a0494196415602d718cc4c.h5
#   Found h5 file: metrics_e8d0c3c042b64c98bca0ab9e4d75b9b4.h5
#   Found h5 file: metrics_5a26f5f0d8324d81bc0bf25846cf828c.h5
#   Found h5 file: metrics_feafa014e64d498480a3d85471be53d8.h5
#   Found h5 file: metrics_93ea69676a6945eaa773f43c5b51b1c6.h5
#   Found h5 file: metrics_a8f3c3716dc74a118a2291b24013af65.h5
#   Found h5 file: metrics_d8486b6fd6854dac8121ac6ee2a60ba1.h5
#   Found h5 file: metrics_4ffba6726bde4766884aa6b9c274c4e4.h5
#   Found h5 file: metrics_074a7fd0354b46339eba02fbfe725b63.h5
#   Found h5 file: metrics_7b1eaca05a0a47fa941b51b9f0d22a42.h5
#   Found h5 file: metrics_267f49165873403f811f6915b1c66b79.h5
#   Found h5 file: metrics_fd44426dab2c49b5bcc615a67ceb30fe.h5
#   Found h5 file: metrics_17c2f01f063c4181856572b71213900d.h5
#   Found h5 file: metrics_c75aeccbeeba48cb860fc53877692b99.h5
#   Found h5 file: metrics_5fa2585fcdaa4d1a8b691ddd65f897f6.h5
#   Found h5 file: metrics_2382a95ba5a44c2caf4026ef6fe6a585.h5
#   Saved timeseries batch (1000000 rows)
#
# Processing batch 121-140/300
#   Found h5 file: metrics_b74e53a2176e467ea5087dc9668017e9.h5
#   Found h5 file: metrics_3aebd4d567f54d61a04b3dad0ff6812f.h5
#   Found h5 file: metrics_b0fd7b938ef34369ba7d2e1219fe9bc8.h5
#   Found h5 file: metrics_7cd8173b42b44454b154739f5023e4bb.h5
#   Found h5 file: metrics_6fe9589cf1ea418c920c11e670447e1c.h5
#   Found h5 file: metrics_ae785456516247db8d3907bcde68ae9e.h5
#   Found h5 file: metrics_77118c3d80b44f439f27e6ad7fbd8db6.h5
#   Found h5 file: metrics_ca435baf471f4432b03a0678726d1297.h5
#   Found h5 file: metrics_2bb916b5ffd84545bad9cbba5186e497.h5
#   Found h5 file: metrics_128e4c7d6cf64c44943a918d98e7d4de.h5
#   Found h5 file: metrics_f4685c28b4b04b5b928dbfa635ace5cf.h5
#   Found h5 file: metrics_74f577d79af04a19bfb2f04a15c27f5a.h5
#   Found h5 file: metrics_1a7543996f2e4eb68e0a7264a4b4dbea.h5
#   Found h5 file: metrics_9df08a62f71d41f09fba72aa8fa01e8d.h5
#   Found h5 file: metrics_e739a6a56e8d431b92ed98402da80035.h5
#   Found h5 file: metrics_2a713b5044c94f72ba3922fb1b2be004.h5
#   Found h5 file: metrics_27a7d7a513b34938b349960726143a0c.h5
#   Found h5 file: metrics_edf2b300771f4f7ab86366880d74c921.h5
#   Found h5 file: metrics_9d9d0292795d4c298b4ddafd90cca452.h5
#   Found h5 file: metrics_760c38a951a540a6843e2cba381f41b7.h5
#   Saved timeseries batch (1000000 rows)
#
# Processing batch 141-160/300
#   Found h5 file: metrics_d5185a5a6f9a461f80b9e0d02f3278a0.h5
#   Found h5 file: metrics_93e646d32629424d8fb7b75c90becc53.h5
#   Found h5 file: metrics_c0b1959e0b3e4104a73ab819c9423977.h5
#   Found h5 file: metrics_6f56aaeec48b4768826bf789f77245b0.h5
#   Found h5 file: metrics_6eee8ac54f584fe087800f0f572e1d56.h5
#   Found h5 file: metrics_c9fc38a699964ec6b7c3fe57eb6cf864.h5
#   Found h5 file: metrics_e1c09006a794436d9831ba5b88bb7901.h5
#   Found h5 file: metrics_80bbccaa1beb4e5683639136b6b9666a.h5
#   Found h5 file: metrics_eca4ea5ab1a54985952646eba3009c90.h5
#   Found h5 file: metrics_768b9db44fe84fe28f2fddedc1dab758.h5
#   Found h5 file: metrics_e7777354c52b4ab9a43226648a9d6e76.h5
#   Found h5 file: metrics_c07f9814b0284b6c94322755056123b5.h5
#   Found h5 file: metrics_4bea978d6c3a40a6b0bc30a4936e35e1.h5
#   Found h5 file: metrics_1b9f3bde13434b7484846e9ce364c9e2.h5
#   Found h5 file: metrics_bddb87edbe1a4b198f856098a470851c.h5
#   Found h5 file: metrics_ed01d8091b034b5d8961fc9d1a324b65.h5
#   Found h5 file: metrics_924d04dba6434fad8c95ea77761f0703.h5
#   Found h5 file: metrics_31d9a365d1fa4cd9a5645984e96054f3.h5
#   Found h5 file: metrics_25e64aa88b784118bbc1b81404dd8f23.h5
#   Found h5 file: metrics_f63cc07f6515439ca1306427c20ac14b.h5
#   Saved timeseries batch (1000000 rows)
#
# Processing batch 161-180/300
#   Found h5 file: metrics_dcf0cc42db6e49e2b6de2aa137e3911b.h5
#   Found h5 file: metrics_82e02d3b10954924999da0cf1f7f6366.h5
#   Found h5 file: metrics_b7f37b533a674cfaa56add742122a6d3.h5
#   Found h5 file: metrics_9bcaf49d8d92418d942cab6a69bced6c.h5
#   Found h5 file: metrics_a38cea3a22b04d3b88589f99577369bd.h5
#   Found h5 file: metrics_9d13c2be699f4a7ab78a8ee8752b6e45.h5
#   Found h5 file: metrics_879ff7f3f3a9426eba609ef244f1f0e2.h5
#   Found h5 file: metrics_aef659f0ab114d22940025a0ed5bb5d4.h5
#   Found h5 file: metrics_96b6e1f4ef144646abb1d463430c78e4.h5
#   Found h5 file: metrics_2b2ba946ed6848038bce6f84931c3ddf.h5
#   Found h5 file: metrics_0a9375a1b49a48cf900ae339b688f0d5.h5
#   Found h5 file: metrics_bc134f94fbcc4d11ae41af1c9792fe03.h5
#   Found h5 file: metrics_ba71295e87354bf2a6b936b6028145d1.h5
#   Found h5 file: metrics_79baf9d06b6b4a3db4288f5422a61f2a.h5
#   Found h5 file: metrics_003ca36d39484c09b1fbb834aa0e9a16.h5
#   Found h5 file: metrics_bc019371f7644754ae41bfe57b9e6a8f.h5
#   Found h5 file: metrics_d262c73a2af744e6a7669e1c7fa2ad29.h5
#   Found h5 file: metrics_59734874878e4bbea47e9ef405cd1c4f.h5
#   Found h5 file: metrics_1903dc168e1a441e97a7039854391ed3.h5
#   Found h5 file: metrics_2ec625842115450bb6db6c7422a065cd.h5
#   Saved timeseries batch (1000000 rows)
#
# Processing batch 181-200/300
#   Found h5 file: metrics_719a5a4cf0534e55bf87ed0ee167ef39.h5
#   Found h5 file: metrics_53e8edd58805435b8dfb5980f96ba87b.h5
#   Found h5 file: metrics_6d716653dc25470781f743235127e10d.h5
#   Found h5 file: metrics_e6d362217c7d4d4290692318fcdcebf6.h5
#   Found h5 file: metrics_ce6c785a95f9438ba19ceb553c73fac1.h5
#   Found h5 file: metrics_57457c8cb59d48b1b28eaa75427af202.h5
#   Found h5 file: metrics_a75cd96abb974f8f8990ef3c875cb42a.h5
#   Found h5 file: metrics_0dfcbefd871848fd838c9314a268bc9f.h5
#   Found h5 file: metrics_9d8989f165c04ca7866cf446b1e9ace3.h5
#   Found h5 file: metrics_b895e3bf3de646ca8b9d9bd65715eff1.h5
#   Found h5 file: metrics_79532c2796834902acf55db62a444dd8.h5
#   Found h5 file: metrics_c907c53a101b4dcfbaa68f1a333f7cc1.h5
#   Found h5 file: metrics_3329f9dad4f14d5e87abf8ddc7d6bccb.h5
#   Found h5 file: metrics_481453346e184d0ca5a10a17653134bb.h5
#   Found h5 file: metrics_ae508cc421964950946dadc0c721bd26.h5
#   Found h5 file: metrics_1e70a638ad70495b9c77969af4488525.h5
#   Found h5 file: metrics_0ba69ce8bbc74e4e96cfdd19bdde54f8.h5
#   Found h5 file: metrics_6f52c7ffd1e74ea88acbf5feda08cd6f.h5
#   Found h5 file: metrics_e352f8056194429fa8b1e1d5c2a6b603.h5
#   Found h5 file: metrics_bd3afab18cc14e53a2768c5aa64c517a.h5
#   Saved timeseries batch (1000000 rows)
#
# Processing batch 201-220/300
#   Found h5 file: metrics_06e86ae9221d474a88a9b872c3b2bd0b.h5
#   Found h5 file: metrics_443a65122a6d4a66be8d7a095ee377fa.h5
#   Found h5 file: metrics_a1c0bfd7fde0472789acb8cad82cd99a.h5
#   Found h5 file: metrics_6e708c2ca1854f9eb52980097efd8628.h5
#   Found h5 file: metrics_87aca483fc344d1d8f4883c2773de6f8.h5
#   Found h5 file: metrics_17b9e9c7eb914d1884c7eec930e0bfdb.h5
#   Found h5 file: metrics_1f166d6821094f25971dc398acf72d04.h5
#   Found h5 file: metrics_949fe452240c467da24161122b3d9fd6.h5
#   Found h5 file: metrics_40aa488dc5134bf5832bd8ddae3da5dd.h5
#   Found h5 file: metrics_d7bba5cf9b1c4375a3cf500b26fb1700.h5
#   Found h5 file: metrics_c6d9577d71bd4c51b5f9baf115543daf.h5
#   Found h5 file: metrics_22292e6f8de5471194343c0ef2ef0b3f.h5
#   Found h5 file: metrics_1def4c8a53754d8c8f1e7e0dd0aac044.h5
#   Found h5 file: metrics_52b0fcfdc4fb4a03b2233fdd79cb7d03.h5
#   Found h5 file: metrics_b8932326ff5d40a0acf18ae462d213bc.h5
#   Found h5 file: metrics_2f14981cf27d4825816bd102600bc5e7.h5
#   Found h5 file: metrics_88cd959fb7434cd2a64d9e966497f31f.h5
#   Found h5 file: metrics_9a667da3694841d5bc66e7911b791396.h5
#   Found h5 file: metrics_77f7e73ee4ac4228b5b9f203e5c22322.h5
#   Found h5 file: metrics_496e80be4e8f4a82ac848a370640bc25.h5
#   Saved timeseries batch (1000000 rows)
#
# Processing batch 221-240/300
#   Found h5 file: metrics_599815d13f6347e6bc55dd12b63aa76f.h5
#   Found h5 file: metrics_cc1c1c4514314df3ad429b6f79e21011.h5
#   Found h5 file: metrics_70f88652f36040b8a9c0874f173e4d8a.h5
#   Found h5 file: metrics_25cf4e28f3ae416c82fa5ad6b9e987db.h5
#   Found h5 file: metrics_caae6a5b35db4ed8911f20eb295c05c5.h5
#   Found h5 file: metrics_60482601994e4bb2b98dd1f345cbf583.h5
#   Found h5 file: metrics_39afb2b8646d4324bba532537f461a39.h5
#   Found h5 file: metrics_24b45ab538d24de8b3da8b1dd6a1b41f.h5
#   Found h5 file: metrics_c9d7b7ab15c14666a1eb18ca0f4c0fbd.h5
#   Found h5 file: metrics_bf5baddbb4b14af59574f378a248b609.h5
#   Found h5 file: metrics_dfda426da1df4ebdae5d3537861d1425.h5
#   Found h5 file: metrics_a2698a190c644dc69766efe4275ca05b.h5
#   Found h5 file: metrics_db88d97e500c46ab9c69e944a910b387.h5
#   Found h5 file: metrics_f6b1d1caee804554813cf9b57505ad9c.h5
#   Found h5 file: metrics_f75cbf39f3e049ca8f131abc6a6f9afb.h5
#   Found h5 file: metrics_509f2f3298354edd841917aa8ec4d95d.h5
#   Found h5 file: metrics_01d27fb5a1ad4c3ba5059e0376d3c36e.h5
#   Found h5 file: metrics_350b7956352d49eaa506a56eb76e04e3.h5
#   Found h5 file: metrics_ec8c89f6f3e44b40a03fffd1639f7e86.h5
#   Found h5 file: metrics_d2fd911be8be4982bd1fb72cc8f93c7c.h5
#   Saved timeseries batch (1000000 rows)
#
# Processing batch 241-260/300
#   Found h5 file: metrics_d587b3a92bf342558acd02b10e88c672.h5
#   Found h5 file: metrics_6292975e6dda410abe39afba70006605.h5
#   Found h5 file: metrics_f6851d04e75f4c6ab364b23fdb6f85c5.h5
#   Found h5 file: metrics_2b3e86d048664c028e26eccc78a44ff6.h5
#   Found h5 file: metrics_6ed7ec4167d74bb2a42df604e1dd945c.h5
#   Found h5 file: metrics_ba54170417de4a2ea6c90779f0bf160b.h5
#   Found h5 file: metrics_7378e58e5fc542dcbbfa7ff704aaa913.h5
#   Found h5 file: metrics_b93e93468929466190f5a0692a680dd6.h5
#   Found h5 file: metrics_dd0e02d79d06414ca62c7c815b667dab.h5
#   Found h5 file: metrics_beb5a32609d64b73b5526292cbd1d4b7.h5
#   Found h5 file: metrics_d03c7332cf1c49ec9a3828724803fae1.h5
#   Found h5 file: metrics_1a9002217aca4ddab01724e5fe073308.h5
#   Found h5 file: metrics_f64c3856d90d41a98e254606dc694d6d.h5
#   Found h5 file: metrics_0b60d9fc82434177b367d1adb7e0b7a2.h5
#   Found h5 file: metrics_ad555bf19f5441e5a1a5839697857d07.h5
#   Found h5 file: metrics_1f42b683aad746c79a8f7117e722d2af.h5
#   Found h5 file: metrics_b302d01fea554e618dc7a267910d38c0.h5
#   Found h5 file: metrics_33dde96ae6bd493ca33a065304bc760c.h5
#   Found h5 file: metrics_b825c5ee040e489b9b01fe3025e97733.h5
#   Found h5 file: metrics_b12331fed17c43b98a17abcdf23fac4e.h5
#   Saved timeseries batch (1000000 rows)
#
# Processing batch 261-280/300
#   Found h5 file: metrics_3dcde314225541bf9f0a4e2e50dd2282.h5
#   Found h5 file: metrics_b83dd9ea1f3a47a6a67b99685dc86867.h5
#   Found h5 file: metrics_2810f744bea0486f88fe91b2a16b7f56.h5
#   Found h5 file: metrics_91f3512d895c4f9c8816d648dccae1fc.h5
#   Found h5 file: metrics_69834c463ddb49a8bcef06a21d993059.h5
#   Found h5 file: metrics_899410761f8f4b9bbc0ba0c3e865986f.h5
#   Found h5 file: metrics_edb6290d890d46d6a4b22cd5c7fa87e8.h5
#   Found h5 file: metrics_5d05e6154b5547d6b0fec8c4836b946a.h5
#   Found h5 file: metrics_45bd40b4557840cea32855f6fefca0e9.h5
#   Found h5 file: metrics_4409f3cb7017445b8acd616ff2702ac3.h5
#   Found h5 file: metrics_37cdb9d0f9a643718d1656173b83ab7c.h5
#   Found h5 file: metrics_5e067bc0abc245958c7f00f2219e8206.h5
#   Found h5 file: metrics_791399716aab4064806edaec61413540.h5
#   Found h5 file: metrics_a618fb9c35a9488ca62093b14bc99121.h5
#   Found h5 file: metrics_49422d56b88d4d2f9277f3dcba39b56d.h5
#   Found h5 file: metrics_f4ca68f3baf942faad74c32f18776d3c.h5
#   Found h5 file: metrics_b3250aca79c844a2ad776b956d069e28.h5
#   Found h5 file: metrics_5a38703d0a594e589ebd757e53a2e6f7.h5
#   Found h5 file: metrics_5839048abf644ed39b6a7c464a905464.h5
#   Found h5 file: metrics_6b0e3efb21d34486aea03ce14cd3fc3e.h5
#   Saved timeseries batch (1000000 rows)
#
# Processing batch 281-300/300
#   Found h5 file: metrics_509e8dcee2004445a5840459e9db2fe3.h5
#   Found h5 file: metrics_ed63747e586541dc8f80b82d0a76fe75.h5
#   Found h5 file: metrics_60fecb18f53b42f5a58f6b3340ee8b08.h5
#   Found h5 file: metrics_de1da20fd3d14fefba1d9d743f42dd3a.h5
#   Found h5 file: metrics_288c9850f76047f6a8a6e1b7ebcacda2.h5
#   Found h5 file: metrics_55f7e24556df4797a7a7086450856add.h5
#   Found h5 file: metrics_4d8ef643e20c41ec95314db7b41b13f0.h5
#   Found h5 file: metrics_0e3aaeb020774033930d8f2d0cf036e4.h5
#   Found h5 file: metrics_f5507f4af17d46b2a57853fc4282b3f8.h5
#   Found h5 file: metrics_6e01b5c8b6ef44778ebcb611a44edc1e.h5
#   Found h5 file: metrics_3556009ef7734637b3e4ab6e6bf3e82d.h5
#   Found h5 file: metrics_b34464a48dd94076b6271ab6a144bcc6.h5
#   Found h5 file: metrics_e04f26758d094cdf8d1da7b7fe82c488.h5
#   Found h5 file: metrics_66c6f804b80f437f8962011ca3c8f9f0.h5
#   Found h5 file: metrics_c9d51313be2f45d4b738a7165e4a1a8c.h5
#   Found h5 file: metrics_1f348801a1b04a5cb13ee3e5b09b6cc0.h5
#   Found h5 file: metrics_d2e761bfb4f44167bd3c36131a15887c.h5
#   Found h5 file: metrics_49875e54f081404597b301e675892c19.h5
#   Found h5 file: metrics_c04e5322408643af86142369a274f310.h5
#   Found h5 file: metrics_628ce0fa92a7460795f4c0e9a59095df.h5
#   Saved timeseries batch (1000000 rows)
#
# Saved metadata (300 rows) to /scratch/clearml/processed_data/fixed_lr_metadata.parquet
#
# === SUMMARY ===
# Total tasks: 300
# H5 files found: 300
# H5 files missing: 0
# Total metadata rows: 300
# Total timeseries rows: 15000000
#
# Loading as Dask DataFrames
#
# Metadata DataFrame: 1 partitions
# Columns: ['task_id', 'task_name', 'config/learners/0/optimizer/_type', 'config/learners/0/optimizer/learning_rate/hyperparameter_parametrization/_type', 'config/learners/0/optimizer/learning_rate/hyperparameter_parametrization/clip', 'config/learners/0/optimizer/learning_rate/learnable', 'config/learners/0/optimizer/learning_rate/value', 'config/learners/1/optimizer/_type', 'config/learners/1/optimizer/learning_rate/hyperparameter_parametrization/_type', 'config/learners/1/optimizer/learning_rate/learnable', 'config/learners/1/optimizer/learning_rate/value', 'config/seed/global_seed', 'metric/final_test_loss', 'metric/final_test_accuracy']
# Sample:
#                             task_id  \
# 0  0104269388204f66940dd66d3ab96e6f
# 1  28ab164aeaf441099d2ad236488f1c2f
# 2  1c5004704a4e46799a26a38517d10ff8
# 3  95c7f79186d84487ba88024d995ee986
# 4  910984d867d34a94b779f9fc81293e73
#
#                                            task_name  \
# 0  base19: config/clearml_run=True config/data/0/...
# 1  base19: config/clearml_run=True config/data/0/...
# 2  base19: config/clearml_run=True config/data/0/...
# 3  base19: config/clearml_run=True config/data/0/...
# 4  base19: config/clearml_run=True config/data/0/...
#
#   config/learners/0/optimizer/_type  \
# 0                         SGDConfig
# 1                         SGDConfig
# 2                         SGDConfig
# 3                         SGDConfig
# 4                         SGDConfig
#
#   config/learners/0/optimizer/learning_rate/hyperparameter_parametrization/_type  \
# 0                                           softrelu
# 1                                           softrelu
# 2                                           softrelu
# 3                                           softrelu
# 4                                           softrelu
#
#   config/learners/0/optimizer/learning_rate/hyperparameter_parametrization/clip  \
# 0                                            10000.0
# 1                                            10000.0
# 2                                            10000.0
# 3                                            10000.0
# 4                                            10000.0
#
#   config/learners/0/optimizer/learning_rate/learnable  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   config/learners/0/optimizer/learning_rate/value  \
# 0                                             0.7
# 1                                             0.3
# 2                                     0.268787538
# 3                                     0.240822469
# 4                                     0.215766928
#
#   config/learners/1/optimizer/_type  \
# 0                        AdamConfig
# 1                        AdamConfig
# 2                        AdamConfig
# 3                        AdamConfig
# 4                        AdamConfig
#
#   config/learners/1/optimizer/learning_rate/hyperparameter_parametrization/_type  \
# 0                                           identity
# 1                                           identity
# 2                                           identity
# 3                                           identity
# 4                                           identity
#
#   config/learners/1/optimizer/learning_rate/learnable  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   config/learners/1/optimizer/learning_rate/value config/seed/global_seed  \
# 0                                            0.01                     760
# 1                                            0.01                     760
# 2                                            0.01                     760
# 3                                            0.01                     760
# 4                                            0.01                     760
#
#    metric/final_test_loss  metric/final_test_accuracy
# 0               28.150732                      0.1000
# 1                0.647279                      0.8818
# 2                0.689146                      0.8891
# 3                0.684965                      0.8899
# 4                0.672752                      0.8861
#
# Timeseries DataFrame: 3 partitions
# Columns: ['task_id', 'iteration', 'metric/train_accuracy', 'metric/train_loss', 'metric/test_accuracy', 'metric/meta_gradient_norm', 'metric/validation_accuracy', 'metric/test_loss', 'metric/validation_loss', 'metric/train_weight_decay', 'metric/train_gradient_norm', 'metric/train_learning_rate']
# Sample:
#                             task_id  iteration  metric/train_accuracy  \
# 0  0104269388204f66940dd66d3ab96e6f          1                   0.05
# 1  0104269388204f66940dd66d3ab96e6f          2                   0.14
# 2  0104269388204f66940dd66d3ab96e6f          3                   0.39
# 3  0104269388204f66940dd66d3ab96e6f          4                   0.20
# 4  0104269388204f66940dd66d3ab96e6f          5                   0.28
#
#    metric/train_loss  metric/test_accuracy  metric/meta_gradient_norm  \
# 0           2.313285                  0.15                        0.0
# 1           2.502353                  0.44                        0.0
# 2           1.994791                  0.18                        0.0
# 3           2.439239                  0.40                        0.0
# 4           2.815923                  0.07                        0.0
#
#    metric/validation_accuracy  metric/test_loss  metric/validation_loss  \
# 0                        0.12          2.465790                2.429150
# 1                        0.42          1.889467                2.088161
# 2                        0.20          2.562401                2.487655
# 3                        0.35          2.567366                2.868370
# 4                        0.11          4.213612                3.838164
#
#    metric/train_weight_decay  metric/train_gradient_norm  \
# 0                        0.0                    0.000000
# 1                        0.0                    1.701396
# 2                        0.0                    3.317932
# 3                        0.0                    2.131505
# 4                        0.0                    4.762318
#
#    metric/train_learning_rate
# 0                         0.7
# 1                         0.7
# 2                         0.7
# 3                         0.7
# 4                         0.7

# %%
# Usage
df_metadata_exp2, df_timeseries_exp2 = download_and_process_tasks_from_h5_normalized(
    tag="opt: d52e9f3fa15d4752a6b684e40633ab2f", 
    experiment_name="oho",
    base_dir="/scratch/clearml/offline_logs/",
    debug_first=True,
    batch_size=20,
    metadata_path="/scratch/clearml/processed_data/oho_metadata.parquet",
    timeseries_path="/scratch/clearml/processed_data/oho_timeseries.parquet"
)
# Out:
# DOWNLOADING TASKS FOR oho: opt: d52e9f3fa15d4752a6b684e40633ab2f
# Found 80 tasks (excluding archived)
# Will save metadata to: /scratch/clearml/processed_data/oho_metadata.parquet
# Will save timeseries to: /scratch/clearml/processed_data/oho_timeseries.parquet
#
# Processing batch 1-20/80
#   Found h5 file: metrics_3d6d68fd50a04b1b8f12b27667494e06.h5
#
# DEBUGGING H5 FILE: /scratch/clearml/offline_logs/metrics_3d6d68fd50a04b1b8f12b27667494e06.h5
# H5 File Structure:
# Dataset: final_test_accuracy
#   Shape: (1,)
#   Dtype: float64
#   Data preview: [0.88879991]
# Dataset: final_test_accuracy_iterations
#   Shape: (1,)
#   Dtype: int32
#   Data preview: [50000]
# Dataset: final_test_loss
#   Shape: (1,)
#   Dtype: float64
#   Data preview: [0.61881298]
# Dataset: final_test_loss_iterations
#   Shape: (1,)
#   Dtype: int32
#   Data preview: [50000]
# Dataset: meta_gradient_norm
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [0.         0.84057343 1.57516515 3.10530829 2.77937746]
# Dataset: meta_gradient_norm_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: test_accuracy
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [0.2        0.16       0.41999999 0.5        0.47      ]
# Dataset: test_accuracy_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: test_loss
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [2.21808195 2.09768009 1.98665941 1.81705892 1.826159  ]
# Dataset: test_loss_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: train_accuracy
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [0.05       0.2        0.17       0.54000002 0.43000001]
# Dataset: train_accuracy_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: train_gradient_norm
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [0.         1.70139623 1.69211912 1.35731375 1.43544245]
# Dataset: train_gradient_norm_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: train_learning_rate
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [0.1        0.1001     0.1001972  0.10029002 0.10038571]
# Dataset: train_learning_rate_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: train_loss
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [2.31328464 2.24060631 2.08317208 1.93514562 1.92813718]
# Dataset: train_loss_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: train_weight_decay
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [0. 0. 0. 0. 0.]
# Dataset: train_weight_decay_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: validation_accuracy
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [0.23999999 0.23999999 0.47       0.44       0.47      ]
# Dataset: validation_accuracy_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
# Dataset: validation_loss
#   Shape: (50000,)
#   Dtype: float64
#   Data preview (first 5): [2.22981238 2.06269908 1.97693098 1.91898108 1.81905103]
# Dataset: validation_loss_iterations
#   Shape: (50000,)
#   Dtype: int32
#   Data preview (first 5): [1 2 3 4 5]
#
# Root level keys: ['final_test_accuracy', 'final_test_accuracy_iterations', 'final_test_loss', 'final_test_loss_iterations', 'meta_gradient_norm', 'meta_gradient_norm_iterations', 'test_accuracy', 'test_accuracy_iterations', 'test_loss', 'test_loss_iterations', 'train_accuracy', 'train_accuracy_iterations', 'train_gradient_norm', 'train_gradient_norm_iterations', 'train_learning_rate', 'train_learning_rate_iterations', 'train_loss', 'train_loss_iterations', 'train_weight_decay', 'train_weight_decay_iterations', 'validation_accuracy', 'validation_accuracy_iterations', 'validation_loss', 'validation_loss_iterations']
#   Found h5 file: metrics_e82cb95ac8e6478289638b415ade4e3a.h5
#   Found h5 file: metrics_a6381d10148843dab031b7d41579872c.h5
#   Found h5 file: metrics_9b0109663ada4079b61e0d0d3b701b3f.h5
#   Found h5 file: metrics_a28a0e999b744abd89043c683be33514.h5
#   Found h5 file: metrics_b25c2644b88e446a84aa159ab580b1f7.h5
#   Found h5 file: metrics_a18116eebd19478fb51aea44b8a28b76.h5
#   Found h5 file: metrics_95a4d8de971b4bfba5f167ebd3a5b7f4.h5
#   Found h5 file: metrics_5645788b8dc945788a970861dcaf13e3.h5
#   Found h5 file: metrics_48e3080c7cf446498751c6e1060ff45d.h5
#   Found h5 file: metrics_9e1fb131636747c1b62654193785f01d.h5
#   Found h5 file: metrics_b09680eb84f848df9e30a3cd2cf8b522.h5
#   Found h5 file: metrics_733be6418b2d40408334219370c585df.h5
#   Found h5 file: metrics_8f65fec3ac6f4d4fbef41d084086d73f.h5
#   Found h5 file: metrics_f73d71538a494bfc9cad605ef35f5cda.h5
#   Found h5 file: metrics_8f01edd13db54d658206c1bc904f8166.h5
#   Found h5 file: metrics_107b24cb3fc944c081f41cd7cab661ff.h5
#   Found h5 file: metrics_44e380762f6349f99cdd7a3a58d7e65e.h5
#   Found h5 file: metrics_9e090d3dea1f418d98302532f22ee665.h5
#   Found h5 file: metrics_27016463332b40e8a2f6035f7251f6e1.h5
#   Saved timeseries batch (1000000 rows)
#
# Processing batch 21-40/80
#   Found h5 file: metrics_c9211bf658bf4a80af3fdb953a9bf2cf.h5
#   Found h5 file: metrics_c334ca47fb7f413cbdbf2fba4ba816a7.h5
#   Found h5 file: metrics_98f3098ee6df42cc8fef021f614dc33e.h5
#   Found h5 file: metrics_29270d2de0c5436ca36f8be1fd96e67f.h5
#   Found h5 file: metrics_7282e0244c5442e1b30824b618facbd8.h5
#   Found h5 file: metrics_a162ae6d53134d9aa12c486e728a4f40.h5
#   Found h5 file: metrics_926f9a1a7d3b4a5997393ee45471dcf6.h5
#   Found h5 file: metrics_f24c89ecdead4befbcaec0f12560b5e5.h5
#   Found h5 file: metrics_cb31eb20a06b465a843477bc1067f7d9.h5
#   Found h5 file: metrics_1e3c71082e06472994089d36f79880c1.h5
#   Found h5 file: metrics_add03f21dfd0478b89f6a7c322bf6f19.h5
#   Found h5 file: metrics_62b582703bc342f69c70fbe83bd4805b.h5
#   Found h5 file: metrics_e1512f27f3c342fb83722c348dc9098e.h5
#   Found h5 file: metrics_3da9ff799cc3495cb1ee5622811fcb35.h5
#   Found h5 file: metrics_6c83a769eaab4d7f99f2912c04d3aaa8.h5
#   Found h5 file: metrics_ee4a9e96c39b4e1a9ed2bc3ef77ba850.h5
#   Found h5 file: metrics_5d7fe04d1dd0476da36f9e0ee2d91d6d.h5
#   Found h5 file: metrics_674c5fc418684d2b8e45aa2f28aadd0f.h5
#   Found h5 file: metrics_f8f221646034480db5ab53fa037e4de4.h5
#   Found h5 file: metrics_bec2b38544bf40efa8bce127c2f7077b.h5
#   Saved timeseries batch (1000000 rows)
#
# Processing batch 41-60/80
#   Found h5 file: metrics_db922ffef4a04650a05b658ff70f77b1.h5
#   Found h5 file: metrics_a307bf169ec14512968c6efad44b0187.h5
#   Found h5 file: metrics_c0a8189e352242ad8eeca23ce82572ea.h5
#   Found h5 file: metrics_ad8cf6ce6149411ca738550e820990c6.h5
#   Found h5 file: metrics_16a25d20b1d34a1b89f5a0b670b81f22.h5
#   Found h5 file: metrics_6fda7ba202f5409a9a0181a76da46bc7.h5
#   Found h5 file: metrics_6bc923c920f94ec6bb7367ed21a556ce.h5
#   Found h5 file: metrics_4744a74864cc430f9a7ce1917a34ac56.h5
#   Found h5 file: metrics_81ef708fd8dd428a9697df36215af510.h5
#   Found h5 file: metrics_a03f6b93b2ce4857a6f50b8097c9117e.h5
#   Found h5 file: metrics_57ed93ad8cd34a64996f187cc94609b3.h5
#   Found h5 file: metrics_fb60e894e18a4350b02a9d72a7f7860d.h5
#   Found h5 file: metrics_3b7ff42e74f045c190f4aef375df7429.h5
#   Found h5 file: metrics_0569ce188e504ade94cd91aa7325f899.h5
#   Found h5 file: metrics_463b2a9fad614285877f8c3676225c07.h5
#   Found h5 file: metrics_80e689ac54544bab86a93e0e2dbd5a0f.h5
#   Found h5 file: metrics_8a03e3a973964faaa9e011829e520676.h5
#   Found h5 file: metrics_f84ee46d087743df8272647b33f31588.h5
#   Found h5 file: metrics_eb8e2286c1c24a4cbee5e766d6241572.h5
#   Found h5 file: metrics_e7d5e63cc7504cbc8a766b099eb15911.h5
#   Saved timeseries batch (1000000 rows)
#
# Processing batch 61-80/80
#   Found h5 file: metrics_4e741db62b0b47fc916c74b53bbfc03b.h5
#   Found h5 file: metrics_051c667051b04f15ac184534debc500e.h5
#   Found h5 file: metrics_62117b06e25941ee9340c5f0f6d3378f.h5
#   Found h5 file: metrics_ea5f9895692f4daa9cdfc3fc09277417.h5
#   Found h5 file: metrics_da753381b92344928a20245b00377c7b.h5
#   Found h5 file: metrics_675a000ad5de4de784c2d6b426269689.h5
#   Found h5 file: metrics_b015680e3590462896e4ccc8b620acb8.h5
#   Found h5 file: metrics_62e70b7cc45b46e4a2e937393749fdd3.h5
#   Found h5 file: metrics_f79836119e2a42b2baabf92d9573d343.h5
#   Found h5 file: metrics_5ccf93aedd424597a39f144a4944d94f.h5
#   Found h5 file: metrics_9362ff8971984ffa9de3dfa6522fc7b1.h5
#   Found h5 file: metrics_a8365225d8974b7e81ec3b0580ab8046.h5
#   Found h5 file: metrics_18ecd5b7f90c449da1d00c2ba8de9ed3.h5
#   Found h5 file: metrics_91fe364faa3f4eda9fd066adf80abf7f.h5
#   Found h5 file: metrics_92ef79ac169f4a78a5e81a3dcf9b34ad.h5
#   Found h5 file: metrics_188f9cf340b64f7797aa9398864211cc.h5
#   Found h5 file: metrics_e52ab4d6ba6743a2ba5f0f263c95750e.h5
#   Found h5 file: metrics_1d5d15c22ebd42b28ff8a0b417cf8177.h5
#   Found h5 file: metrics_d5a1dd59b6e34788b0cbe0f98d9153d9.h5
#   Found h5 file: metrics_c203c6bfbd984c0e8b79d1746dd3b105.h5
#   Saved timeseries batch (1000000 rows)
#
# Saved metadata (80 rows) to /scratch/clearml/processed_data/oho_metadata.parquet
#
# === SUMMARY ===
# Total tasks: 80
# H5 files found: 80
# H5 files missing: 0
# Total metadata rows: 80
# Total timeseries rows: 4000000
#
# Loading as Dask DataFrames
#
# Metadata DataFrame: 1 partitions
# Columns: ['task_id', 'task_name', 'config/seed/global_seed', 'config/learners/0/optimizer/learning_rate/value', 'config/learners/0/optimizer/learning_rate/learnable', 'config/learners/0/optimizer/learning_rate/hyperparameter_parametrization/clip', 'config/learners/0/optimizer/learning_rate/hyperparameter_parametrization/_type', 'config/learners/0/optimizer/_type', 'config/learners/1/optimizer/learning_rate/value', 'config/learners/1/optimizer/learning_rate/learnable', 'config/learners/1/optimizer/learning_rate/hyperparameter_parametrization/_type', 'config/learners/1/optimizer/_type', 'metric/final_test_loss', 'metric/final_test_accuracy']
# Sample:
#                             task_id  \
# 0  3d6d68fd50a04b1b8f12b27667494e06
# 1  e82cb95ac8e6478289638b415ade4e3a
# 2  a6381d10148843dab031b7d41579872c
# 3  9b0109663ada4079b61e0d0d3b701b3f
# 4  a28a0e999b744abd89043c683be33514
#
#                                            task_name config/seed/global_seed  \
# 0  base18: config/clearml_run=True config/data/0/...                     760
# 1  base18: config/clearml_run=True config/data/0/...                     760
# 2  base18: config/clearml_run=True config/data/0/...                     760
# 3  base18: config/clearml_run=True config/data/0/...                     760
# 4  base18: config/clearml_run=True config/data/0/...                     202
#
#   config/learners/0/optimizer/learning_rate/value  \
# 0                                             0.1
# 1                                            0.01
# 2                                           0.001
# 3                                          0.0001
# 4                                             0.1
#
#   config/learners/0/optimizer/learning_rate/learnable  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   config/learners/0/optimizer/learning_rate/hyperparameter_parametrization/clip  \
# 0                                            10000.0
# 1                                            10000.0
# 2                                            10000.0
# 3                                            10000.0
# 4                                            10000.0
#
#   config/learners/0/optimizer/learning_rate/hyperparameter_parametrization/_type  \
# 0                                           softrelu
# 1                                           softrelu
# 2                                           softrelu
# 3                                           softrelu
# 4                                           softrelu
#
#   config/learners/0/optimizer/_type  \
# 0                         SGDConfig
# 1                         SGDConfig
# 2                         SGDConfig
# 3                         SGDConfig
# 4                         SGDConfig
#
#   config/learners/1/optimizer/learning_rate/value  \
# 0                                          0.0001
# 1                                          0.0001
# 2                                          0.0001
# 3                                          0.0001
# 4                                          0.0001
#
#   config/learners/1/optimizer/learning_rate/learnable  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   config/learners/1/optimizer/learning_rate/hyperparameter_parametrization/_type  \
# 0                                           identity
# 1                                           identity
# 2                                           identity
# 3                                           identity
# 4                                           identity
#
#   config/learners/1/optimizer/_type  metric/final_test_loss  \
# 0                        AdamConfig                0.618813
# 1                        AdamConfig                0.338239
# 2                        AdamConfig                0.674254
# 3                        AdamConfig                0.577231
# 4                        AdamConfig                0.387369
#
#    metric/final_test_accuracy
# 0                      0.8888
# 1                      0.8913
# 2                      0.8818
# 3                      0.8754
# 4                      0.8898
#
# Timeseries DataFrame: 1 partitions
# Columns: ['task_id', 'iteration', 'metric/train_accuracy', 'metric/train_loss', 'metric/test_accuracy', 'metric/meta_gradient_norm', 'metric/validation_accuracy', 'metric/test_loss', 'metric/validation_loss', 'metric/train_weight_decay', 'metric/train_gradient_norm', 'metric/train_learning_rate']
# Sample:
#                             task_id  iteration  metric/train_accuracy  \
# 0  3d6d68fd50a04b1b8f12b27667494e06          1                   0.05
# 1  3d6d68fd50a04b1b8f12b27667494e06          2                   0.20
# 2  3d6d68fd50a04b1b8f12b27667494e06          3                   0.17
# 3  3d6d68fd50a04b1b8f12b27667494e06          4                   0.54
# 4  3d6d68fd50a04b1b8f12b27667494e06          5                   0.43
#
#    metric/train_loss  metric/test_accuracy  metric/meta_gradient_norm  \
# 0           2.313285                  0.20                   0.000000
# 1           2.240606                  0.16                   0.840573
# 2           2.083172                  0.42                   1.575165
# 3           1.935146                  0.50                   3.105308
# 4           1.928137                  0.47                   2.779377
#
#    metric/validation_accuracy  metric/test_loss  metric/validation_loss  \
# 0                        0.24          2.218082                2.229812
# 1                        0.24          2.097680                2.062699
# 2                        0.47          1.986659                1.976931
# 3                        0.44          1.817059                1.918981
# 4                        0.47          1.826159                1.819051
#
#    metric/train_weight_decay  metric/train_gradient_norm  \
# 0                        0.0                    0.000000
# 1                        0.0                    1.701396
# 2                        0.0                    1.692119
# 3                        0.0                    1.357314
# 4                        0.0                    1.435442
#
#    metric/train_learning_rate
# 0                    0.100000
# 1                    0.100100
# 2                    0.100197
# 3                    0.100290
# 4                    0.100386

# %%
# Usage
experiments = [
    ("Fixed LR", df_metadata_exp1, df_timeseries_exp1),
    ("OHO", df_metadata_exp2, df_timeseries_exp2),
]

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

def power_law(t, a, b, c):
    return a * (t + 1) ** (-b) + c

def plot_final_loss_and_effective_lr_violins(experiments):
    """
    Plot violin plots for final test loss and effective learning rate across experiments.
    Only uses tasks from the BEST learning rate configuration.
    
    Args:
        experiments: list of tuples (name, df_metadata, df_timeseries)
    """
    n_experiments = len(experiments)
    
    all_final_losses = []
    all_eff_lrs = []
    experiment_data = []
    
    for name, df_metadata, df_timeseries in experiments:
        print(f"\n{'='*60}")
        print(f"Processing {name}...")
        print(f"{'='*60}")
        
        metadata = df_metadata.compute()
        
        lr_cols = ['config/learners/0/optimizer/learning_rate/value', 
                   'config/learners/1/optimizer/learning_rate/value']
        
        # Group by LR config and get mean final test loss
        lr_summary = metadata.groupby(lr_cols)['metric/final_test_loss'].agg(['mean', 'std', 'count']).reset_index()
        lr_summary = lr_summary.sort_values('mean')
        
        print(f"\nAll configurations ranked by mean final test loss:")
        print("-" * 80)
        for rank, (_, row) in enumerate(lr_summary.iterrows(), start=1):
            lr0, lr1 = row[lr_cols[0]], row[lr_cols[1]]
            print(f"Rank {rank}: LR0={float(lr0):.6f}, LR1={float(lr1):.6f} | "
                f"mean={row['mean']:.6f}, std={row['std']:.6f}, n={int(row['count'])}")
        
        # Best config is the one with LOWEST final test loss
        best_config = lr_summary.iloc[0]
        best_lr0 = best_config[lr_cols[0]]
        best_lr1 = best_config[lr_cols[1]]
        config_str = f"LR0={float(best_lr0):.6f}, LR1={float(best_lr1):.6f}"
        
        print(f"\n{'*'*80}")
        print(f"BEST CONFIG: {config_str}")
        print(f"Mean final test loss: {best_config['mean']:.6f}")
        print(f"{'*'*80}")
        
        # Filter metadata to best config
        best_metadata = metadata[
            (metadata[lr_cols[0]] == best_lr0) & 
            (metadata[lr_cols[1]] == best_lr1)
        ]
        
        # Get final test losses for best config
        final_losses = best_metadata['metric/final_test_loss'].dropna().values
        best_task_ids = best_metadata['task_id'].values
        
        # Compute effective learning rates from test loss curves for best config tasks
        timeseries = df_timeseries.compute()
        eff_lrs = []
        
        for task_id in best_task_ids:
            task_data = timeseries[timeseries['task_id'] == task_id]
            if len(task_data) > 5 and 'metric/test_loss' in task_data.columns:
                try:
                    iterations = task_data['iteration'].values
                    test_losses = task_data['metric/test_loss'].dropna().values
                    if len(test_losses) > 5:
                        popt, _ = curve_fit(power_law, iterations[:len(test_losses)], test_losses,
                                          bounds=([0,0,0], [np.inf,np.inf,np.inf]), maxfev=2000)
                        eff_lrs.append(popt[1])
                except:
                    continue
        
        eff_lrs = np.array(eff_lrs)
        
        experiment_data.append({
            'name': name,
            'config': config_str,
            'final_losses': final_losses,
            'eff_lrs': eff_lrs
        })
        
        all_final_losses.extend(final_losses)
        all_eff_lrs.extend(eff_lrs)
        
        print(f"\nBest config statistics:")
        print(f"  Final losses: {len(final_losses)} tasks")
        print(f"  Effective LRs: {len(eff_lrs)} tasks")
    
    # Calculate shared y-axis limits
    final_loss_ylim = (min(all_final_losses) * 0.95, max(all_final_losses) * 1.05)
    eff_lr_ylim = (min(all_eff_lrs) * 0.95, max(all_eff_lrs) * 1.05)
    
    # Create plots
    fig, axes = plt.subplots(2, n_experiments, figsize=(4 * n_experiments, 8))
    if n_experiments == 1:
        axes = axes.reshape(2, 1)
    
    for i, data in enumerate(experiment_data):
        # Final test loss
        axes[0, i].violinplot([data['final_losses']], positions=[0], showmeans=True, showmedians=True)
        mean_val, std_val = np.mean(data['final_losses']), np.std(data['final_losses'])
        axes[0, i].text(0.95, 0.95, f'μ={mean_val:.4f}\nσ={std_val:.4f}', 
                       transform=axes[0, i].transAxes, va='top', ha='right',
                       bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
        axes[0, i].set_title(f"{data['name']}: Final Test Loss\n{data['config']}", fontsize=10)
        axes[0, i].set_ylabel("Final Test Loss")
        axes[0, i].set_xticks([0])
        axes[0, i].set_xticklabels([data['name']])
        axes[0, i].set_ylim(final_loss_ylim)
        
        # Effective learning rate
        if len(data['eff_lrs']) > 0:
            axes[1, i].violinplot([data['eff_lrs']], positions=[0], showmeans=True, showmedians=True)
            mean_val, std_val = np.mean(data['eff_lrs']), np.std(data['eff_lrs'])
            axes[1, i].text(0.95, 0.95, f'μ={mean_val:.4f}\nσ={std_val:.4f}', 
                           transform=axes[1, i].transAxes, va='top', ha='right',
                           bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
            axes[1, i].set_ylim(eff_lr_ylim)
        else:
            axes[1, i].text(0.5, 0.5, "No Data", ha="center", va="center", 
                           transform=axes[1, i].transAxes)
        
        axes[1, i].set_title(f"{data['name']}: Effective LR\n{data['config']}", fontsize=10)
        axes[1, i].set_ylabel("Effective Learning Rate")
        axes[1, i].set_xticks([0])
        axes[1, i].set_xticklabels([data['name']])
    
    plt.tight_layout()
    plt.show()



plot_final_loss_and_effective_lr_violins(experiments)
# Out:
# ============================================================
# Processing Fixed LR...
# ============================================================
#
# All configurations ranked by mean final test loss:
# --------------------------------------------------------------------------------
# Rank 1: LR0=0.010000, LR1=0.010000 | mean=0.346722, std=0.005498, n=20
# Rank 2: LR0=0.001000, LR1=0.010000 | mean=0.440459, std=0.001924, n=20
# Rank 3: LR0=0.100000, LR1=0.010000 | mean=0.574486, std=0.024062, n=20
# Rank 4: LR0=0.111612, LR1=0.010000 | mean=0.601445, std=0.030958, n=20
# Rank 5: LR0=0.124573, LR1=0.010000 | mean=0.610997, std=0.019011, n=20
# Rank 6: LR0=0.139039, LR1=0.010000 | mean=0.632957, std=0.035206, n=20
# Rank 7: LR0=0.173205, LR1=0.010000 | mean=0.642969, std=0.016136, n=20
# Rank 8: LR0=0.155185, LR1=0.010000 | mean=0.644525, std=0.042089, n=20
# Rank 9: LR0=0.215767, LR1=0.010000 | mean=0.657379, std=0.018452, n=20
# Rank 10: LR0=0.193318, LR1=0.010000 | mean=0.658420, std=0.024195, n=20
# Rank 11: LR0=0.300000, LR1=0.010000 | mean=0.666053, std=0.030084, n=20
# Rank 12: LR0=0.240822, LR1=0.010000 | mean=0.666986, std=0.029852, n=20
# Rank 13: LR0=0.268788, LR1=0.010000 | mean=0.674724, std=0.020043, n=20
# Rank 14: LR0=0.000100, LR1=0.010000 | mean=0.682050, std=0.007545, n=20
# Rank 15: LR0=0.700000, LR1=0.010000 | mean=11.065519, std=16.738215, n=20
#
# ********************************************************************************
# BEST CONFIG: LR0=0.010000, LR1=0.010000
# Mean final test loss: 0.346722
# ********************************************************************************
#
# Best config statistics:
#   Final losses: 20 tasks
#   Effective LRs: 20 tasks
#
# ============================================================
# Processing OHO...
# ============================================================
#
# All configurations ranked by mean final test loss:
# --------------------------------------------------------------------------------
# Rank 1: LR0=0.010000, LR1=0.000100 | mean=0.406936, std=0.124377, n=20
# Rank 2: LR0=0.000100, LR1=0.000100 | mean=0.437082, std=0.116600, n=20
# Rank 3: LR0=0.001000, LR1=0.000100 | mean=0.451467, std=0.135731, n=20
# Rank 4: LR0=0.100000, LR1=0.000100 | mean=0.472328, std=0.131207, n=20
#
# ********************************************************************************
# BEST CONFIG: LR0=0.010000, LR1=0.000100
# Mean final test loss: 0.406936
# ********************************************************************************
#
# Best config statistics:
#   Final losses: 20 tasks
#   Effective LRs: 20 tasks

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

def power_law(t, a, b, c):
    return a * (t + 1) ** (-b) + c

def plot_average_test_loss_curves_with_powerlaw(experiments):
    """
    Plot average test loss curves with averaged power law fits.
    Fits power law to each task individually, then averages the parameters.
    
    Args:
        experiments: list of tuples (name, df_metadata, df_timeseries)
    """
    fig, ax = plt.subplots(1, 1, figsize=(12, 8))
    
    colors = ['blue', 'red', 'green', 'purple', 'orange']
    
    for idx, (name, df_metadata, df_timeseries) in enumerate(experiments):
        print(f"\nProcessing {name}...")
        color = colors[idx % len(colors)]
        
        metadata = df_metadata.compute()
        
        # Find best config
        lr_cols = ['config/learners/0/optimizer/learning_rate/value', 
                   'config/learners/1/optimizer/learning_rate/value']
        lr_summary = metadata.groupby(lr_cols)['metric/final_test_loss'].mean().reset_index()
        lr_summary = lr_summary.sort_values('metric/final_test_loss')
        best_config = lr_summary.iloc[0]
        best_lr0 = best_config[lr_cols[0]]
        best_lr1 = best_config[lr_cols[1]]
        
        print(f"  Best config: LR0={float(best_lr0):.6f}, LR1={float(best_lr1):.6f}")
        
        # Filter to best config
        best_metadata = metadata[
            (metadata[lr_cols[0]] == best_lr0) & 
            (metadata[lr_cols[1]] == best_lr1)
        ]
        best_task_ids = best_metadata['task_id'].values
        
        # Get timeseries for best config
        timeseries = df_timeseries.compute()
        best_timeseries = timeseries[timeseries['task_id'].isin(best_task_ids)]
        
        # Compute average test loss curve
        avg_curve = best_timeseries.groupby('iteration')['metric/test_loss'].mean()
        iterations = avg_curve.index.values
        avg_test_losses = avg_curve.values
        
        # Fit power law to each individual task and collect parameters
        power_law_params = []
        for task_id in best_task_ids:
            task_data = timeseries[timeseries['task_id'] == task_id]
            if len(task_data) > 5:
                try:
                    task_iterations = task_data['iteration'].values
                    task_losses = task_data['metric/test_loss'].dropna().values
                    if len(task_losses) > 5:
                        popt, _ = curve_fit(power_law, task_iterations[:len(task_losses)], task_losses,
                                          bounds=([0,0,0], [np.inf,np.inf,np.inf]), maxfev=2000)
                        power_law_params.append(popt)
                except:
                    continue
        
        if power_law_params:
            # Average the power law parameters
            avg_a = np.mean([p[0] for p in power_law_params])
            avg_b = np.mean([p[1] for p in power_law_params])
            avg_c = np.mean([p[2] for p in power_law_params])
            
            print(f"  Averaged power law params: a={avg_a:.4f}, b={avg_b:.4f}, c={avg_c:.4f}")
            print(f"  Number of tasks used: {len(power_law_params)}")
            
            # Generate power law curve using averaged parameters
            fitted_curve = power_law(iterations, avg_a, avg_b, avg_c)
            
            # Plot both
            ax.plot(iterations, avg_test_losses, color=color, linewidth=2, alpha=0.7, 
                   label=f'{name} (avg curve)', linestyle='-')
            ax.plot(iterations, fitted_curve, color='black', linewidth=2, alpha=0.9,
                   label=f'{name} (avg power law)', linestyle='--')
        else:
            print(f"  Failed to fit power laws")
            ax.plot(iterations, avg_test_losses, color=color, linewidth=2, 
                   label=f'{name} (avg curve)')
    
    ax.set_xlabel('Iteration')
    ax.set_ylabel('Test Loss')
    ax.set_title('Average Test Loss Curves with Averaged Power Law Fits (Best Config)')
    ax.legend()
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()



plot_average_test_loss_curves_with_powerlaw(experiments)
# Out:
# Processing Fixed LR...
#   Best config: LR0=0.010000, LR1=0.010000
#   Averaged power law params: a=4.9507, b=0.3729, c=0.2511
#   Number of tasks used: 20
#
# Processing OHO...
#   Best config: LR0=0.010000, LR1=0.000100
#   Averaged power law params: a=5.8772, b=0.5143, c=0.3297
#   Number of tasks used: 20

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import uniform_filter1d

def plot_test_loss_and_lr_curves_by_seed(experiments, smooth_window=100):
    """
    Plot smoothed test loss curves and learning rate curves for each seed individually.
    
    Args:
        experiments: list of tuples (name, df_metadata, df_timeseries)
        smooth_window: window size for smoothing
    """
    for name, df_metadata, df_timeseries in experiments:
        print(f"\nProcessing {name}...")
        
        metadata = df_metadata.compute()
        
        # Find best config
        lr_cols = ['config/learners/0/optimizer/learning_rate/value', 
                   'config/learners/1/optimizer/learning_rate/value']
        lr_summary = metadata.groupby(lr_cols)['metric/final_test_loss'].mean().reset_index()
        lr_summary = lr_summary.sort_values('metric/final_test_loss')
        best_config = lr_summary.iloc[0]
        best_lr0 = best_config[lr_cols[0]]
        best_lr1 = best_config[lr_cols[1]]
        
        print(f"  Best config: LR0={float(best_lr0):.6f}, LR1={float(best_lr1):.6f}")
        
        # Filter to best config
        best_metadata = metadata[
            (metadata[lr_cols[0]] == best_lr0) & 
            (metadata[lr_cols[1]] == best_lr1)
        ]
        
        # Get timeseries for best config
        timeseries = df_timeseries.compute()
        best_task_ids = best_metadata['task_id'].values
        best_timeseries = timeseries[timeseries['task_id'].isin(best_task_ids)]
        
        # Merge with metadata to get seeds
        best_timeseries_with_seed = best_timeseries.merge(
            best_metadata[['task_id', 'config/seed/global_seed']], 
            on='task_id'
        )
        
        # Get unique seeds
        seeds = sorted(best_timeseries_with_seed['config/seed/global_seed'].unique())
        print(f"  Number of seeds: {len(seeds)}")
        
        # Create subplots - 2 rows (test loss + LR) per seed
        n_seeds = len(seeds)
        n_cols = 5
        n_rows = ((n_seeds + n_cols - 1) // n_cols) * 2  # 2 rows per seed group
        
        fig, axes = plt.subplots(n_rows, n_cols, figsize=(4 * n_cols, 4 * n_rows))
        axes = axes.reshape(n_rows, n_cols)
        
        # Plot test loss and LR curve for each seed
        for idx, seed in enumerate(seeds):
            col = idx % n_cols
            row_base = (idx // n_cols) * 2
            
            seed_data = best_timeseries_with_seed[
                best_timeseries_with_seed['config/seed/global_seed'] == seed
            ].sort_values('iteration')
            
            iterations = seed_data['iteration'].values
            test_losses = seed_data['metric/test_loss'].values
            
            # Smooth test loss
            smoothed_test_losses = uniform_filter1d(test_losses, size=smooth_window)
            
            # Plot test loss
            axes[row_base, col].plot(iterations, smoothed_test_losses, linewidth=1.5)
            axes[row_base, col].set_xlabel('Iteration')
            axes[row_base, col].set_ylabel('Test Loss (smoothed)')
            axes[row_base, col].set_title(f'Seed {int(seed)} - Test Loss')
            axes[row_base, col].grid(True, alpha=0.3)
            
            # Plot learning rate
            if 'metric/train_learning_rate' in seed_data.columns:
                learning_rates = seed_data['metric/train_learning_rate'].values
                axes[row_base + 1, col].plot(iterations, learning_rates, linewidth=1.5, color='orange')
                axes[row_base + 1, col].set_xlabel('Iteration')
                axes[row_base + 1, col].set_ylabel('Learning Rate')
                axes[row_base + 1, col].set_title(f'Seed {int(seed)} - Learning Rate')
                axes[row_base + 1, col].grid(True, alpha=0.3)
                axes[row_base + 1, col].set_yscale('log')
            else:
                axes[row_base + 1, col].text(0.5, 0.5, 'No LR data', 
                                            ha='center', va='center',
                                            transform=axes[row_base + 1, col].transAxes)
                axes[row_base + 1, col].set_title(f'Seed {int(seed)} - Learning Rate')
        
        # Hide unused subplots
        total_used = ((n_seeds + n_cols - 1) // n_cols) * 2
        for row in range(total_used, n_rows):
            for col in range(n_cols):
                axes[row, col].axis('off')
        
        # Hide unused columns in last row group
        last_group_start = (len(seeds) // n_cols) * 2
        used_in_last_group = len(seeds) % n_cols
        if used_in_last_group > 0:
            for col in range(used_in_last_group, n_cols):
                axes[last_group_start, col].axis('off')
                axes[last_group_start + 1, col].axis('off')
        
        fig.suptitle(f'{name}: Test Loss & LR Curves by Seed (smoothing window={smooth_window})\n'
                    f'LR0={float(best_lr0):.6f}, LR1={float(best_lr1):.6f}', 
                    fontsize=14)
        plt.tight_layout()
        plt.show()


plot_test_loss_and_lr_curves_by_seed(experiments, smooth_window=100)
# Out:
# Processing Fixed LR...
#   Best config: LR0=0.010000, LR1=0.010000
#   Number of seeds: 20
# Processing OHO...
#   Best config: LR0=0.010000, LR1=0.000100
#   Number of seeds: 20
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
